# %%
import numpy as np
import pandas as pd
import random

# %%
amostra=[random.randint(1,444) for i in range (50)]
print(amostra)
dados=np.array(amostra)
print(dados)
# Out:
# [49, 344, 84, 6, 105, 372, 77, 277, 304, 247, 312, 315, 398, 147, 226, 159, 84, 98, 161, 327, 393, 4, 201, 63, 106, 144, 73, 408, 239, 126, 424, 46, 202, 439, 433, 248, 441, 42, 195, 202, 54, 28, 300, 86, 41, 274, 382, 252, 257, 285]
# [ 49 344  84   6 105 372  77 277 304 247 312 315 398 147 226 159  84  98
#  161 327 393   4 201  63 106 144  73 408 239 126 424  46 202 439 433 248
#  441  42 195 202  54  28 300  86  41 274 382 252 257 285]

# %%
df_salarios=pd.DataFrame(amostra, columns=['Salário'])
display(df_salarios)
# Out:
#     Salário
# 0        49
# 1       344
# 2        84
# 3         6
# 4       105
# 5       372
# 6        77
# 7       277
# 8       304
# 9       247
# 10      312
# 11      315
# 12      398
# 13      147
# 14      226
# 15      159
# 16       84
# 17       98
# 18      161
# 19      327
# 20      393
# 21        4
# 22      201
# 23       63
# 24      106
# 25      144
# 26       73
# 27      408
# 28      239
# 29      126
# 30      424
# 31       46
# 32      202
# 33      439
# 34      433
# 35      248
# 36      441
# 37       42
# 38      195
# 39      202
# 40       54
# 41       28
# 42      300
# 43       86
# 44       41
# 45      274
# 46      382
# 47      252
# 48      257
# 49      285

# %%
assimetria=df_salarios['Salário'].skew()
media=df_salarios['Salário'].mean()
mediana=df_salarios['Salário'].median()

print(f'Assimetria:{assimetria}')
print(f'Média:{media}')
print(f'Mediana:{mediana}')
# Out:
# Assimetria:0.18851437468737026
# Média:209.6
# Mediana:202.0

# %%
curtose=df_salarios['Salário'].kurtosis()
print(f'Curtose:{curtose}')
# Out:
# Curtose:-1.1946205898900082

# %%
if -0.5 <= assimetria <= 0.5:
    resultado="Distribuição Simetrica"
elif assimetria>0.5:
    resultado="Distribuição Assimetrica Positiva"
else:
    resultado="Distribuição Assimetrica Negativa"

print(resultado)
# Out:
# Distribuição Simetrica

# %%
import matplotlib.pyplot as plt

plt.boxplot(df_salarios['Salário'])
plt.title('Boxplot dos Salário')
plt.ylabel('Salário')
plt.show()
